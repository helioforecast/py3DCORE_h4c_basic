# %% [markdown]
# # Fitting py3DCORE_h4c
#
# Notebook to produce shortterm forecasts of magnetic flux ropes with the 3DCORE model.

# %%
# %load_ext autoreload

# %autoreload 2

import heliosat as heliosat
import logging as logging
import datetime as datetime
import numpy as np
import os as os
import pickle as pickle
import py3dcore_h4c as py3dcore_h4c
import matplotlib.pyplot as plt
import shutil as shutil
import pandas as pds
import event as evt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from heliosat.util import sanitize_dt

logging.basicConfig(level=logging.INFO)
logging.getLogger("heliosat.spice").setLevel("WARNING")
logging.getLogger("heliosat.spacecraft").setLevel("WARNING")

# %% [markdown]
# ## ICMECAT
#
# We first read the catalog and save all events in lists.

# %%
wincat,stacat,stbcat,pspcat,solocat,bepicat,ulycat,messcat,vexcat = evt.get_cat()

i1au = wincat + stacat + stbcat
print('ICMECAT events near 1 AU',len(i1au))
# Out:
# got wincat: 448
# got stacat: 258
# got stbcat: 150
# got pspcat: 35
# got solocat: 34
# got bepicat: 32
# got ulycat: 0
# got messcat: 0
# got vexcat: 93
# ICMECAT events near 1 AU 856

# %% [markdown]
# We now choose a specific event we want to fit.

# %%
winevent = evt.findevent(wincat, year=2012,month=5,day=16)

print('Start of event: '+str(winevent[0].begin))
print('Start of MC: '+str(winevent[0].cloud))
print('End of event: '+str(winevent[0].end))
# Out:
# Number of events in time interval: 1
# Start of event: 2012-05-16 12:28:00+00:00
# Start of MC: 2012-05-16 16:04:00+00:00
# End of event: 2012-05-18 02:11:00+00:00

# %% [markdown]
# We set the launch time for the CME, t_launch (as observed), and two points in time (t_s and t_e), that lie outside of our fitting range. These function as reference points to check, whether an ensemble is actually hitting our spacecraft within the time window. Furthermore, we set fitting points, t, to which the flux rope model will be fitted.
#
# For a shortterm forecast, we can estimate the launch time and t_s from observations. The end marker, t_e, is then estimated using t_s and adding a few days - with this, we want to guarantee that t_e lies outside of the flux rope.

# %%
#t_launch = winevent[0].begin-datetime.timedelta(days=4)

t_launch = datetime.datetime(2012, 5, 12, 10,tzinfo=datetime.timezone.utc)

t_s_wind = datetime.datetime(2012, 5, 16, 16, tzinfo=datetime.timezone.utc)
t_e_wind = t_s_wind + datetime.timedelta(hours=30)

t_wind = [
    datetime.datetime(2012, 5, 17, tzinfo=datetime.timezone.utc),
    datetime.datetime(2012, 5, 17, 3, tzinfo=datetime.timezone.utc)
]

# %% [markdown]
# Restraining the initial values for the ensemble members leads to more efficient fitting.
#
#     Model Parameters
#     ================
#         For this specific model there are a total of 14 initial parameters which are as follows:
#         0: t_i          time offset
#         1: lon          longitude
#         2: lat          latitude
#         3: inc          inclination
#
#         4: dia          cross section diameter at 1 AU
#         5: delta        cross section aspect ratio
#
#         6: r0           initial cme radius
#         7: v0           initial cme velocity
#         8: T            T factor (related to the twist)
#
#         9: n_a          expansion rate
#         10: n_b         magnetic field decay rate
#
#         11: b           magnetic field strength at center at 1AU
#         12: bg_d        solar wind background drag coefficient
#         13: bg_v        solar wind background speed
#
#         There are 4 state parameters which are as follows:
#         0: v_t          current velocity
#         1: rho_0        torus major radius
#         2: rho_1        torus minor radius
#         3: b_t          magnetic field strength at center

# %%
model_kwargs = {
    "ensemble_size": int(2**16),
    "iparams": {
        "cme_longitude": {
            "maximum": 15,
            "minimum": 0
        },
        "cme_latitude": {
            "maximum": 10,
            "minimum": -10
        },
        "cme_inclination": {
            "maximum": 235,
            "minimum": 225
        }, 
        "cme_diameter_1au": {
            "maximum": 0.16,
            "minimum": 0.14
        }, 
        "cme_aspect_ratio": {
            "maximum": 6,
            "minimum": 1
        },
        "cme_launch_velocity": {
            "maximum": 750,
            "minimum": 650
        },
        "background_velocity": {
            "maximum": 310,
            "minimum": 280
        }
    }
}

# %%
#"cme_launch_offset": {
#    "distribution": "uniform",
#    "maximum": 3600*24,
#    "minimum": -3600*24
#}

# %% [raw]
# #first clean output folder
# output="out_wind_heeq/"
#
# # Deleting an non-empty folder
# try:
#     shutil.rmtree(output, ignore_errors=True)
#     print("Deleted '%s' directory successfully" % output)
# except:
#     pass

# %%
output = 'out_wind_heeq_shortterm_test1_1024/'

fitter = py3dcore_h4c.ABC_SMC()
fitter.initialize(t_launch, py3dcore_h4c.ToroidalModel, model_kwargs)
fitter.add_observer("WIND", t_wind, t_s_wind, t_e_wind)

# set jobs=8, workers=8, to avoid using all CPU cores

fitter.run(ensemble_size=1024, reference_frame="HEEQ", sampling_freq=3600, output=output, eps_quantile=.25)
# Out:
# INFO:py3dcore_h4c.fitter.abc_smc:running iteration 0
# INFO:py3dcore_h4c.fitter.abc_smc:initial eps_init = [1.38643483]
# INFO:py3dcore_h4c.fitter.abc_smc:starting simulations
# INFO:py3dcore_h4c.fitter.abc_smc:step 0:0 with (23057/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:setting new eps: [1.38643483] => [0.89985234]
# INFO:py3dcore_h4c.fitter.abc_smc:step 0 done, 1024 particles, 0.52M runs in 12.86 seconds, (total: 00h 00m 12s)
# INFO:py3dcore_h4c.fitter.abc_smc:running iteration 1
# INFO:py3dcore_h4c.fitter.abc_smc:starting simulations
# INFO:py3dcore_h4c.fitter.abc_smc:step 1:0 with (21836/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:setting new eps: [0.89985234] => [0.64219171]
# INFO:py3dcore_h4c.fitter.abc_smc:step 1 done, 1024 particles, 0.52M runs in 21.26 seconds, (total: 00h 00m 34s)
# INFO:py3dcore_h4c.fitter.abc_smc:running iteration 2
# INFO:py3dcore_h4c.fitter.abc_smc:starting simulations
# INFO:py3dcore_h4c.fitter.abc_smc:step 2:0 with (9452/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:setting new eps: [0.64219171] => [0.48197905]
# INFO:py3dcore_h4c.fitter.abc_smc:step 2 done, 1024 particles, 0.52M runs in 20.31 seconds, (total: 00h 00m 54s)
# INFO:py3dcore_h4c.fitter.abc_smc:running iteration 3
# INFO:py3dcore_h4c.fitter.abc_smc:starting simulations
# INFO:py3dcore_h4c.fitter.abc_smc:step 3:0 with (3157/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:setting new eps: [0.48197905] => [0.3700586]
# INFO:py3dcore_h4c.fitter.abc_smc:step 3 done, 1024 particles, 0.52M runs in 20.01 seconds, (total: 00h 01m 14s)
# INFO:py3dcore_h4c.fitter.abc_smc:running iteration 4
# INFO:py3dcore_h4c.fitter.abc_smc:starting simulations
# INFO:py3dcore_h4c.fitter.abc_smc:step 4:0 with (871/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 4:1 with (1768/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:setting new eps: [0.3700586] => [0.28367507]
# INFO:py3dcore_h4c.fitter.abc_smc:step 4 done, 1024 particles, 1.05M runs in 39.30 seconds, (total: 00h 01m 53s)
# INFO:py3dcore_h4c.fitter.abc_smc:running iteration 5
# INFO:py3dcore_h4c.fitter.abc_smc:starting simulations
# INFO:py3dcore_h4c.fitter.abc_smc:step 5:0 with (235/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 5:1 with (463/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 5:2 with (675/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 5:3 with (928/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 5:4 with (1188/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:setting new eps: [0.28367507] => [0.22513607]
# INFO:py3dcore_h4c.fitter.abc_smc:step 5 done, 1024 particles, 2.62M runs in 94.26 seconds, (total: 00h 03m 27s)
# INFO:py3dcore_h4c.fitter.abc_smc:running iteration 6
# INFO:py3dcore_h4c.fitter.abc_smc:starting simulations
# INFO:py3dcore_h4c.fitter.abc_smc:step 6:0 with (75/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 6:1 with (141/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 6:2 with (212/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 6:3 with (284/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 6:4 with (344/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 6:5 with (417/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 6:6 with (492/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 6:7 with (556/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 6:8 with (622/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 6:9 with (687/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 6:10 with (743/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 6:11 with (800/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 6:12 with (875/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 6:13 with (942/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 6:14 with (1006/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 6:15 with (1074/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:setting new eps: [0.22513607] => [0.17792072]
# INFO:py3dcore_h4c.fitter.abc_smc:step 6 done, 1024 particles, 8.39M runs in 297.44 seconds, (total: 00h 08m 25s)
# INFO:py3dcore_h4c.fitter.abc_smc:running iteration 7
# INFO:py3dcore_h4c.fitter.abc_smc:starting simulations
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:0 with (15/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:1 with (32/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:2 with (44/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:3 with (61/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:4 with (73/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:5 with (92/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:6 with (109/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:7 with (123/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:8 with (144/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:9 with (153/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:10 with (179/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:11 with (194/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:12 with (214/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:13 with (231/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:14 with (242/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:15 with (252/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:16 with (268/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:17 with (281/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:18 with (288/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:19 with (304/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:20 with (324/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:21 with (346/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:22 with (362/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:23 with (378/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:24 with (396/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:25 with (423/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:26 with (443/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:27 with (464/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:28 with (478/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:29 with (494/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:30 with (502/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:31 with (520/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:32 with (535/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:33 with (550/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:34 with (565/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:35 with (580/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:36 with (590/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:37 with (608/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:38 with (620/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:39 with (634/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:40 with (649/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:41 with (663/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:42 with (677/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:43 with (689/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:44 with (708/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:45 with (722/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:46 with (737/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:47 with (750/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:48 with (770/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:49 with (784/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:50 with (797/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:51 with (807/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:52 with (822/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:53 with (838/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:54 with (858/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:55 with (876/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:56 with (889/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:57 with (906/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:58 with (927/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:59 with (941/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:60 with (954/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:61 with (965/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:62 with (980/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:63 with (991/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:64 with (1006/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 7:65 with (1026/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:setting new eps: [0.17792072] => [0.14192237]
# INFO:py3dcore_h4c.fitter.abc_smc:step 7 done, 1024 particles, 34.60M runs in 1253.27 seconds, (total: 00h 29m 18s)
# INFO:py3dcore_h4c.fitter.abc_smc:running iteration 8
# INFO:py3dcore_h4c.fitter.abc_smc:starting simulations
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:0 with (7/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:1 with (13/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:2 with (14/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:3 with (18/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:4 with (22/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:5 with (26/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:6 with (33/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:7 with (35/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:8 with (38/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:9 with (43/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:10 with (47/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:11 with (49/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:12 with (52/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:13 with (58/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:14 with (60/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:15 with (65/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:16 with (70/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:17 with (78/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:18 with (83/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:19 with (87/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:20 with (88/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:21 with (93/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:22 with (96/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:23 with (99/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:24 with (106/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:25 with (111/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:26 with (118/1024) particles
# INFO:py3dcore_h4c.fitter.abc_smc:step 8:27 with (126/1024) particles
# Process SpawnPoolWorker-27:
# Process SpawnPoolWorker-26:
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-25:
# Process SpawnPoolWorker-24:
# Process SpawnPoolWorker-23:
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     res = self._reader.recv_bytes()
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/connection.py", line 221, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-29:
# Process SpawnPoolWorker-28:
# Process SpawnPoolWorker-30:
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/opt/homebrew/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/x3/2bzh843n0tv469w6l6sd8sq00000gn/T/ipykernel_5336/1735440785.py in <cell line: 7>()
#       5 fitter.add_observer("WIND", t_wind, t_s_wind, t_e_wind)
#       6
# ----> 7 fitter.run(ensemble_size=1024, reference_frame="HEEQ", jobs=8, workers=8, sampling_freq=3600, output=output_test, eps_quantile=.25)
#
# ~/Documents/Arbeit/ASWO/3DCORE/py3DCORE_h4c/py3dcore_h4c/fitter/abc_smc.py in run(self, epsgoal, iter_min, iter_max, ensemble_size, reference_frame, **kwargs)
#     132                     _random_seed = random_seed + 100000 * iter_i + 1000 * (sub_iter_i + 1)
#     133
# --> 134                     _results_ext = starmap(abc_smc_worker, [(*worker_args, _random_seed + i) for i in range(jobs)])
#     135                     _results.extend(_results_ext)
#     136
#
# ~/Documents/Arbeit/ASWO/3DCORE/py3DCORE_h4c/py3dcore_h4c/fitter/abc_smc.py in starmap(func, args)
#      22
#      23 def starmap(func, args):
# ---> 24     return [func(*_) for _ in args]
#      25
#      26
#
# ~/Documents/Arbeit/ASWO/3DCORE/py3DCORE_h4c/py3dcore_h4c/fitter/abc_smc.py in <listcomp>(.0)
#      22
#      23 def starmap(func, args):
# ---> 24     return [func(*_) for _ in args]
#      25
#      26
#
# ~/Documents/Arbeit/ASWO/3DCORE/py3DCORE_h4c/py3dcore_h4c/fitter/abc_smc.py in abc_smc_worker(*args)
#     216
#     217     # generate synthetic profiles
# --> 218     profiles = np.array(model_obj.simulator(np.array(data_obj.data_dt)[sort_index], np.array(data_obj.data_o)[sort_index])[0], dtype=model_obj.dtype)
#     219
#     220     # resort profiles
#
# ~/Documents/Arbeit/ASWO/3DCORE/py3DCORE_h4c/py3dcore_h4c/model.py in simulator(self, dt, pos, sparams)
#     115         for i in range(len(dt)):  # type: ignore
#     116             self.propagator(dt[i])  # type: ignore
# --> 117             self.simulator_mag(pos[i], b_out[i])
#     118
#     119             if sparams and len(sparams) > 0:
#
# ~/Documents/Arbeit/ASWO/3DCORE/py3DCORE_h4c/py3dcore_h4c/models/toroidal/__init__.py in simulator_mag(self, pos, out)
#      79
#      80             if self.mag_model == "gh":
# ---> 81                 thin_torus_gh(_q_tmp, self.iparams_arr, self.sparams_arr, self.qs_xs, out)
#      82             else:
#      83                 raise NotImplementedError
#
# KeyboardInterrupt:

# %% [markdown]
# now that the fitting is completed, we look at the results.

# %%
# Get the list of all files 
path = output

# Get the list of all files in path
dir_list = sorted(os.listdir(path))

resfile = []
# we only want the pickle-files
for file in dir_list:
    if file.endswith(".pickle"):
        #respath.append(os.path.join(path, file)) 
        resfile.append(file)
        print(os.path.join(path, file))
# Out:
# Files and directories in ' out_wind_heeq_shortterm_test1_1024/ ' :
# ['00.pickle', '01.pickle', '02.pickle', '03.pickle', '04.pickle', '05.pickle', '06.pickle', '07.pickle']
# out_wind_heeq_shortterm_test1_1024/07.pickle

# %%
t_s_wind = datetime.datetime(2012, 5, 16, tzinfo=datetime.timezone.utc)
t_e_wind = datetime.datetime(2012, 5, 18, tzinfo=datetime.timezone.utc)

wind_t, wind_b = heliosat.WIND().get([t_s_wind, t_e_wind], "mag", reference_frame="HEEQ", as_endpoints=True, return_datetimes=True, smoothing="gaussian")

for dirl in resfile:
    
    respath = path + dirl
    ed = py3dcore_h4c.generate_ensemble(respath, wind_t, reference_frame="HEEQ", reference_frame_to="HEEQ", max_index=128)

    plt.figure(figsize=(28, 12))
    plt.title("Wind fitting result")
    plt.plot(wind_t, np.sqrt(np.sum(wind_b**2, axis=1)), "k", alpha=0.5)
    plt.plot(wind_t, wind_b[:, 0], "r", alpha=0.5)
    plt.plot(wind_t, wind_b[:, 1], "g", alpha=0.5)
    plt.plot(wind_t, wind_b[:, 2], "b", alpha=0.5)
    plt.fill_between(wind_t, ed[0][3][0], ed[0][3][1], alpha=0.25, color="k")
    plt.fill_between(wind_t, ed[0][2][0][:, 0], ed[0][2][1][:, 0], alpha=0.25, color="r")
    plt.fill_between(wind_t, ed[0][2][0][:, 1], ed[0][2][1][:, 1], alpha=0.25, color="g")
    plt.fill_between(wind_t, ed[0][2][0][:, 2], ed[0][2][1][:, 2], alpha=0.25, color="b")
    plt.ylabel("B [nT]")
    plt.xlabel("Time [MM-DD HH]")
    for _ in t_wind:
        plt.axvline(x=_, lw=1, alpha=0.25, color="k", ls="--")
    plt.savefig(path+'%s.png' % dirl)
    plt.show()
# Out:
# /Users/uteamerstorfer/Documents/Arbeit/ASWO/3DCORE/py3DCORE_h4c/py3dcore_h4c/fitter/base.py:40: RuntimeWarning: Mean of empty slice
#   b_m = np.nanmean(ensemble, axis=1)
# /opt/homebrew/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1583: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# /Users/uteamerstorfer/Documents/Arbeit/ASWO/3DCORE/py3DCORE_h4c/py3dcore_h4c/fitter/base.py:46: RuntimeWarning: Mean of empty slice
#   b_tm = np.nanmean(b_t, axis=1)
